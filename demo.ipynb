# %% [markdown]
# # Zero Shot Captcha Solver - Demo
#
# Below is a quick demo that showcases the zero-shot capabilities of this application in solving these type of Captchas.
# For a more detailed explaination on how this works, please refer to the README.

# %% [markdown]
# ### 0. Imports

# %%
import zero_shot_captcha_solver
from PIL import Image

# %% [markdown]
# ### 1. Load Example Image

# %%
IMAGE = "examples/motorbike.jpg"
Image.open(IMAGE)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### 2. Solve Captcha

# %%
zero_shot_captcha_solver.solve_captcha_from_path(IMAGE)
# Out:
# array([[False,  True,  True],
#        [False,  True, False],
#        [False, False,  True]])
